# %% [markdown]
# # 46 CodeChallenge: Manipulate Regression Slope

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline

# set the backend for matplotlib
matplotlib_inline.backend_inline.set_matplotlib_formats('svg', 'png')

# %%
# import pytorch
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"using device: {device}")
# Out:
# using device: cuda

# %%
# create data
N = 30
x = torch.randn(N, 1)
y = x + torch.randn(N, 1) * 0.5

# plot data
plt.plot(x,y,'s')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Data')
plt.show()

# %%
# Build a linear regression model
ANNreg = nn.Sequential(
    nn.Linear(1, 1),
    nn.ReLU(),
    nn.Linear(1, 1)
)
# print the model
print(ANNreg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Build a linear regression model
# ----> 2 ANNreg = nn.Sequential(
#       3     nn.Linear(1, 1),
#       4     nn.ReLU(),
#       5     nn.Linear(1, 1)
#       6 )
#       7 # print the model
#       8 print(ANNreg)
#
# NameError: name 'nn' is not defined

# %%
# learning rate
lr = 0.05

# loss function
loss_fn = nn.MSELoss()

# optimizer
optimizer = torch.optim.SGD(ANNreg.parameters(), lr=lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 lr = 0.05
#       4 # loss function
# ----> 5 loss_fn = nn.MSELoss()
#       7 # optimizer
#       8 optimizer = torch.optim.SGD(ANNreg.parameters(), lr=lr)
#
# NameError: name 'nn' is not defined

# %%
# train the model
epochs = 100
losses = torch.zeros(epochs)

## training loop
